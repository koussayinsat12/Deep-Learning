# %% [markdown]
# ## Imoporter Les bibliothèques nécessiaires

# %%
from utils import *
from models.perceptron import *
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Compléxite de l'algorithme en temps=O(n^2)
# Complexité de l'algorithme en Espace=O(n)

# %%
X, y = datasets.make_blobs (n_samples=150, n_features=2,
centers=2, cluster_std=1.05,
random_state=2)
#Plotting
fig = plt.figure(figsize=(10, 8))
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
classes=[1,0]

# %%
w,nmiss_list=perceptron(X,y,labels=classes,lr=0.1,epochs=20,log=True)
# Out:
# Start of epoch 0
# number of misclassified examples:  14
# Time taken: 0.00s
#
# Start of epoch 1
# number of misclassified examples:  0
# Time taken: 0.02s
#
# Start of epoch 2
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 3
# number of misclassified examples:  0
# Time taken: 0.02s
#
# Start of epoch 4
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 5
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 6
# number of misclassified examples:  0
# Time taken: 0.02s
#
# Start of epoch 7
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 8
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 9
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 10
# number of misclassified examples:  0
# Time taken: 0.02s
#
# Start of epoch 11
# number of misclassified examples:  0
# Time taken: 0.00s
#
# Start of epoch 12
# ...

# %%
fig = plt.figure(figsize=(10, 8))
# Assuming X is your data matrix and y is your label vector
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^', label='Class 0')  # Plotting class 0 in red triangles
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs', label='Class 1')  # Plotting class 1 in blue squares
# Assuming you already have w calculated
plot_decision_boundary(X, w)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.title('Random Classification Data with 2 classes')
plt.show()

# %%
classes=[0,-1]

# %% [markdown]
# ### Experience 1

# %%
mu1=np.array([-1,0])
m2=np.array([1,0])
variance1=0.25
variance2=0.25
dic_data=generate_data(mu1=mu1,mu2=m2,variance1=variance1,variance2=variance2,test_size=0.2)

# %%
dic_data.keys()
# Out:
# dict_keys(['train_data', 'test_data', 'train_labels', 'test_labels'])

# %%
dic_data['train_data']
# Out:
# array([[ 1.05173004e+00, -2.54358228e-02],
#        [-9.93124204e-01,  3.83666817e-01],
#        [ 1.19320577e+00, -4.92410452e-01],
#        [ 2.13205022e+00,  9.41808430e-03],
#        [ 1.17784368e+00, -3.99399784e-01],
#        [ 9.85594965e-01,  1.14713744e-01],
#        [ 1.39361496e+00,  7.18112445e-02],
#        [-2.57989174e-01, -7.27687821e-01],
#        [-1.47123740e+00,  9.00936118e-01],
#        [ 8.83438296e-02,  5.99784618e-01],
#        [ 1.48146263e+00,  3.12907529e-02],
#        [-7.86182322e-01,  3.78270546e-01],
#        [-9.94626189e-01, -4.36090711e-01],
#        [ 2.21480571e+00,  1.25140063e-01],
#        [-1.57000478e+00, -1.46318016e-01],
#        [ 3.94160817e-01, -1.07714451e+00],
#        [ 6.92805651e-01,  5.20142976e-01],
#        [ 1.20846350e+00, -7.66153945e-01],
#        [ 1.14807638e+00,  3.89261674e-01],
#        [ 2.31328910e-01,  4.17541790e-01],
#        [-1.33423502e+00,  8.96048229e-03],
#        [-5.77702252e-01,  2.10818023e-01],
# ...

# %%
X_train,y_train,X_test,y_test=dic_data['train_data'],dic_data['train_labels'],dic_data['test_data'],dic_data['test_labels']

# %%
X_train,y_train=dic_data["train_data"],dic_data["train_labels"]
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class 0')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 1')  # Plotting class 1 in blue squares
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
w,_=perceptron(X_train,y_train,labels=classes,lr=0.1,epochs=20)

# %%
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_train, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Decision Boundary on train Set')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on train Set')

# %% [markdown]
# **Interprétation**:
# L'algorithme ne converge pas car le Perceptron utilise des frontières de décision linéaires pour séparer les classes. Si les données ne peuvent pas être séparées par une seule droite (ou hyperplan dans des dimensions supérieures), le Perceptron ne pourra pas converger vers une solution satisfaisante

# %%
w,_=perceptron(X_train,y_train,labels=classes,lr=0.1,epochs=20,init="random")
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_train, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title("Decision Boundary on the Train Set with Random Initialization of Weights")
# Out:
# Text(0.5, 1.0, 'Decision Boundary on the Train Set with Random Initialization of Weights')

# %% [markdown]
# **Interprétation**:
# La limite de décision ne peut pas être unique, car elle peut varier en fonction de l'initialisation des poids, du nombre d'epochs et de la valeur du pas d'apprentissage.

# %%
predictions=predict(X_test,labels=classes,w=w)
score = accuracy_score(predictions,y_test)
print(f'accuracy =  {int(score*100)} %')
# Out:
# accuracy =  96 %

# %%
fig = plt.figure(figsize=(10, 8))
plt.plot(X_test[:, 0][y_test == -1], X_test[:, 1][y_test == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_test[:, 0][y_test == 0], X_test[:, 1][y_test == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_test, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Decision Boundary on Test Set')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Set')

# %% [markdown]
# ### Experience 2

# %%
mu1=np.array([-1,0])
m2=np.array([1,0])
variance1=0.75
variance2=0.75
dic_data=generate_data(mu1=mu1,mu2=m2,variance1=variance1,variance2=variance2,test_size=0.2)

# %%
X_train,y_train,X_test,y_test=dic_data['train_data'],dic_data['train_labels'],dic_data['test_data'],dic_data['test_labels']
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class 0')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 1')  # Plotting class 1 in blue squares
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
w,_=perceptron(X_train,y_train,labels=classes,lr=0.1,epochs=20)

# %%
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_train, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Decision Boundary on train dataset')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on train dataset')

# %% [markdown]
# **Interprétation**:
# L'algorithme ne converge pas. En fait Dans cette expérience, avec une variance plus élevée dans les données générées, celles-ci sont plus dispersées dans l'espace des caractéristiques, ce qui complique davantage la tâche de séparation linéaire pour le Perceptron

# %%
w,_=perceptron(X_train,y_train,labels=classes,lr=0.1,epochs=20,init="random")
fig = plt.figure(figsize=(10, 8))
plt.plot(X_train[:, 0][y_train == -1], X_train[:, 1][y_train == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_train[:, 0][y_train == 0], X_train[:, 1][y_train == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_train, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title("Decision Boundary on the Train Dataset with Random Initialization of Weights")
# Out:
# Text(0.5, 1.0, 'Decision Boundary on the Train Dataset with Random Initialization of Weights')

# %% [markdown]
# **Interprétation**:
# La limite de décision ne peut pas être unique, car elle peut varier en fonction de l'initialisation des poids, du nombre d'epochs et de la valeur du pas d'apprentissage.

# %%
predictions=predict(X_test,labels=classes,w=w)
score = accuracy_score(y_test,predictions)
print(f'accuracy =  {int(score*100)} %')
# Out:
# accuracy =  88 %

# %%
fig = plt.figure(figsize=(10, 8))
plt.plot(X_test[:, 0][y_test == -1], X_test[:, 1][y_test == -1], 'r^', label='Class -1')  # Plotting class 0 in red triangles
plt.plot(X_test[:, 0][y_test == 0], X_test[:, 1][y_test == 0], 'bs', label='Class 0')  # Plotting class 1 in blue squares
plot_decision_boundary(X_test, w)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Decision Boundary on Test Set')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Set')

# %% [markdown]
# ### Experince 3

# %%
def experiment(variance, num_experiments=30):
    errors = np.zeros(num_experiments)  # Initialize as a 1D array
    for k in range(num_experiments):
        # Générer les données d'entraînement et de test
        dic_data=generate_data(mu1=mu1,mu2=m2,variance1=variance,variance2=variance,test_size=0.2)
        X_train, y_train, X_test, y_test = dic_data['train_data'], dic_data['train_labels'], dic_data['test_data'], dic_data['test_labels']
        # Entraîner le modèle
        w, _ = perceptron(X_train, y_train, labels=classes, lr=0.1, epochs=20)
        y_pred = predict(X_test, labels=classes, w=w)
        # Calculer l'erreur
        errors[k] = 1 - accuracy_score(y_test, y_pred)
    return errors

variances = [0.01, 0.1, 0.5, 0.7]
num_experiments = 30
mean_errors = []
variance_errors = []
for variance in variances:
    errors = experiment(variance, num_experiments)
    mean_errors.append(np.mean(errors))
    variance_errors.append(np.var(errors))

plt.figure(figsize=(10, 6))
plt.errorbar(variances, mean_errors, yerr=np.sqrt(variance_errors), fmt='-o')
plt.xlabel("Variances")
plt.ylabel("Error")
plt.title("Impact de la variation de σ1^2 et σ2^2 sur l'erreur")
plt.show()

# %% [markdown]
# **Interprétation :**
# Plus la variance des données générées augmente, plus l'erreur du Perceptron risque d'augmenter. Cela est dû au fait que des données avec une variance plus élevée peuvent être plus dispersées dans l'espace des caractéristiques, rendant ainsi la tâche de séparation linéaire plus difficile pour le Perceprton
